# %%
# !nvidia-smi
# Out:
# Thu Dec  9 07:06:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Conv2D,  MaxPool2D, Flatten, GlobalAveragePooling2D,  BatchNormalization, Layer, Add
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model

from tensorflow.keras import datasets
from keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import OneHotEncoder

# %%
(x_train, x_test),(y_train, y_test) = datasets.cifar10.load_data()

encoder = OneHotEncoder()
encoder.fit(x_test)
x_test = encoder.transform(x_test).toarray()
y_test = encoder.transform(y_test).toarray()


train_datagen=ImageDataGenerator(rescale=1/255)
test_datagen=ImageDataGenerator(rescale=1/255)
train_generator = train_datagen.flow(
    x_train, y=x_test, batch_size=256, shuffle=True
)
test_generator = test_datagen.flow(
    y_train, y=y_test, batch_size=64, shuffle=False
)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
class BasicBlock(tf.keras.layers.Layer):

    def __init__(self, filter_num, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(3, 3),
                                            strides=stride,
                                            padding="same")
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(3, 3),
                                            strides=1,
                                            padding="same")
        self.bn2 = tf.keras.layers.BatchNormalization()
        if stride != 1:
            self.downsample = tf.keras.Sequential()
            self.downsample.add(tf.keras.layers.Conv2D(filters=filter_num,
                                                       kernel_size=(1, 1),
                                                       strides=stride))
            self.downsample.add(tf.keras.layers.BatchNormalization())
        else:
            self.downsample = lambda x: x

    def call(self, inputs, training=None, **kwargs):
        residual = self.downsample(inputs)

        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv2(x)
        x = self.bn2(x, training=training)

        output = tf.nn.relu(tf.keras.layers.add([residual, x]))

        return output


class BottleNeck(tf.keras.layers.Layer):
    def __init__(self, filter_num, stride=1):
        super(BottleNeck, self).__init__()
        self.conv1 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(1, 1),
                                            strides=1,
                                            padding='same')
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(3, 3),
                                            strides=stride,
                                            padding='same')
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.conv3 = tf.keras.layers.Conv2D(filters=filter_num * 4,
                                            kernel_size=(1, 1),
                                            strides=1,
                                            padding='same')
        self.bn3 = tf.keras.layers.BatchNormalization()

        self.downsample = tf.keras.Sequential()
        self.downsample.add(tf.keras.layers.Conv2D(filters=filter_num * 4,
                                                   kernel_size=(1, 1),
                                                   strides=stride))
        self.downsample.add(tf.keras.layers.BatchNormalization())

    def call(self, inputs, training=None, **kwargs):
        residual = self.downsample(inputs)

        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv2(x)
        x = self.bn2(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv3(x)
        x = self.bn3(x, training=training)

        output = tf.nn.relu(tf.keras.layers.add([residual, x]))

        return output


def make_basic_block_layer(filter_num, blocks, stride=1):
    res_block = tf.keras.Sequential()
    res_block.add(BasicBlock(filter_num, stride=stride))

    for _ in range(1, blocks):
        res_block.add(BasicBlock(filter_num, stride=1))

    return res_block


def make_bottleneck_layer(filter_num, blocks, stride=1):
    res_block = tf.keras.Sequential()
    res_block.add(BottleNeck(filter_num, stride=stride))

    for _ in range(1, blocks):
        res_block.add(BottleNeck(filter_num, stride=1))

    return res_block

# %%
class ResNetTypeI(tf.keras.Model):
    def __init__(self, layer_params):
        super(ResNetTypeI, self).__init__()

        self.conv1 = tf.keras.layers.Conv2D(filters=64,
                                            kernel_size=(7, 7),
                                            strides=2,
                                            padding="same")
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.pool1 = tf.keras.layers.MaxPool2D(pool_size=(3, 3),
                                               strides=2,
                                               padding="same")

        self.layer1 = make_basic_block_layer(filter_num=64,
                                             blocks=layer_params[0])
        self.layer2 = make_basic_block_layer(filter_num=128,
                                             blocks=layer_params[1],
                                             stride=2)
        self.layer3 = make_basic_block_layer(filter_num=256,
                                             blocks=layer_params[2],
                                             stride=2)
        self.layer4 = make_basic_block_layer(filter_num=512,
                                             blocks=layer_params[3],
                                             stride=2)

        self.avgpool = tf.keras.layers.GlobalAveragePooling2D()
        self.fc = tf.keras.layers.Dense(units=10, activation=tf.keras.activations.softmax)

    def call(self, inputs, training=None, mask=None):
        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.pool1(x)
        x = self.layer1(x, training=training)
        x = self.layer2(x, training=training)
        x = self.layer3(x, training=training)
        x = self.layer4(x, training=training)
        x = self.avgpool(x)
        output = self.fc(x)

        return output


    def call(self, inputs, training=None, mask=None):
        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.pool1(x)
        x = self.layer1(x, training=training)
        x = self.layer2(x, training=training)
        x = self.layer3(x, training=training)
        x = self.layer4(x, training=training)
        x = self.avgpool(x)
        output = self.fc(x)

        return output


def resnet_18():
    return ResNetTypeI(layer_params=[2, 2, 2, 2])

# %%
model = resnet_18()

# %%
model.build(input_shape = (None,32,32,3))
model.compile(optimizer = "adam",loss='categorical_crossentropy', metrics=["accuracy"]) 
model.summary()
# Out:
# Model: "res_net_type_i_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          multiple                  9472
#
#  batch_normalization_40 (Bat  multiple                 256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  multiple                 0
#  2D)
#
#  sequential_14 (Sequential)  (None, None, None, 64)    148736
#
#  sequential_15 (Sequential)  (None, None, None, 128)   527488
#
#  sequential_17 (Sequential)  (None, None, None, 256)   2103552
#
#  sequential_19 (Sequential)  (None, None, None, 512)   8401408
#
#  global_average_pooling2d_2   multiple                 0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             multiple                  5130
#
# =================================================================
# Total params: 11,196,042
# Trainable params: 11,186,442
# Non-trainable params: 9,600
# _________________________________________________________________

# %%
model.fit(
    train_generator,
    epochs=50,
    validation_data = test_generator
)
# Out:
# Epoch 1/50
# 196/196 [==============================] - 30s 128ms/step - loss: 1.4580 - accuracy: 0.4855 - val_loss: 2.7009 - val_accuracy: 0.1876
# Epoch 2/50
# 196/196 [==============================] - 23s 119ms/step - loss: 1.0291 - accuracy: 0.6338 - val_loss: 2.1574 - val_accuracy: 0.3632
# Epoch 3/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.8443 - accuracy: 0.7013 - val_loss: 1.2730 - val_accuracy: 0.5885
# Epoch 4/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.7208 - accuracy: 0.7471 - val_loss: 1.3642 - val_accuracy: 0.5773
# Epoch 5/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.6166 - accuracy: 0.7822 - val_loss: 1.0314 - val_accuracy: 0.6639
# Epoch 6/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.5222 - accuracy: 0.8144 - val_loss: 1.1926 - val_accuracy: 0.6212
# Epoch 7/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.4462 - accuracy: 0.8428 - val_loss: 1.4549 - val_accuracy: 0.5847
# Epoch 8/50
# 196/196 [==============================] - 23s 118ms/step - loss: 0.3692 - accuracy: 0.8682 - val_loss: 1.4232 - val_accuracy: 0.6228
# Epoch 9/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.3072 - accuracy: 0.8910 - val_loss: 1.2440 - val_accuracy: 0.6636
# Epoch 10/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.2485 - accuracy: 0.9115 - val_loss: 1.2421 - val_accuracy: 0.6740
# Epoch 11/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.2073 - accuracy: 0.9268 - val_loss: 1.2395 - val_accuracy: 0.6889
# Epoch 12/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1770 - accuracy: 0.9371 - val_loss: 1.3171 - val_accuracy: 0.6789
# Epoch 13/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1465 - accuracy: 0.9488 - val_loss: 1.3711 - val_accuracy: 0.6981
# Epoch 14/50
# 196/196 [==============================] - 23s 118ms/step - loss: 0.1367 - accuracy: 0.9510 - val_loss: 1.4425 - val_accuracy: 0.6826
# Epoch 15/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1159 - accuracy: 0.9589 - val_loss: 1.2575 - val_accuracy: 0.7217
# Epoch 16/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0940 - accuracy: 0.9668 - val_loss: 1.8170 - val_accuracy: 0.6489
# Epoch 17/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.1017 - accuracy: 0.9644 - val_loss: 1.2122 - val_accuracy: 0.7353
# Epoch 18/50
# 196/196 [==============================] - 23s 120ms/step - loss: 0.0807 - accuracy: 0.9721 - val_loss: 1.8227 - val_accuracy: 0.6755
# Epoch 19/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0860 - accuracy: 0.9704 - val_loss: 1.6516 - val_accuracy: 0.6865
# Epoch 20/50
# 196/196 [==============================] - 24s 121ms/step - loss: 0.0812 - accuracy: 0.9713 - val_loss: 1.5695 - val_accuracy: 0.7016
# Epoch 21/50
# 196/196 [==============================] - 24s 122ms/step - loss: 0.0669 - accuracy: 0.9771 - val_loss: 1.5080 - val_accuracy: 0.7114
# Epoch 22/50
# 196/196 [==============================] - 24s 121ms/step - loss: 0.0753 - accuracy: 0.9734 - val_loss: 1.5254 - val_accuracy: 0.7040
# Epoch 23/50
# 196/196 [==============================] - 24s 122ms/step - loss: 0.0502 - accuracy: 0.9831 - val_loss: 1.9114 - val_accuracy: 0.6607
# Epoch 24/50
# 196/196 [==============================] - 24s 121ms/step - loss: 0.0728 - accuracy: 0.9748 - val_loss: 1.6636 - val_accuracy: 0.7154
# Epoch 25/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0550 - accuracy: 0.9812 - val_loss: 1.6805 - val_accuracy: 0.7101
# Epoch 26/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0526 - accuracy: 0.9817 - val_loss: 1.8161 - val_accuracy: 0.7061
# Epoch 27/50
# 196/196 [==============================] - 23s 118ms/step - loss: 0.0676 - accuracy: 0.9768 - val_loss: 1.5089 - val_accuracy: 0.7268
# Epoch 28/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0468 - accuracy: 0.9843 - val_loss: 1.5827 - val_accuracy: 0.7082
# Epoch 29/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0510 - accuracy: 0.9817 - val_loss: 1.6875 - val_accuracy: 0.7083
# Epoch 30/50
# 196/196 [==============================] - 23s 118ms/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 1.8707 - val_accuracy: 0.6993
# Epoch 31/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0456 - accuracy: 0.9848 - val_loss: 1.5755 - val_accuracy: 0.7256
# Epoch 32/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0538 - accuracy: 0.9817 - val_loss: 1.7524 - val_accuracy: 0.7023
# Epoch 33/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0365 - accuracy: 0.9875 - val_loss: 1.5322 - val_accuracy: 0.7234
# Epoch 34/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0424 - accuracy: 0.9853 - val_loss: 1.8523 - val_accuracy: 0.7050
# Epoch 35/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0434 - accuracy: 0.9851 - val_loss: 1.4633 - val_accuracy: 0.7347
# Epoch 36/50
# 196/196 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9851Epoch 37/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0391 - accuracy: 0.9868 - val_loss: 1.6653 - val_accuracy: 0.7140
# Epoch 38/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0477 - accuracy: 0.9833 - val_loss: 1.4684 - val_accuracy: 0.7370
# Epoch 39/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0307 - accuracy: 0.9896 - val_loss: 1.8259 - val_accuracy: 0.7117
# Epoch 40/50
# 196/196 [==============================] - 23s 120ms/step - loss: 0.0377 - accuracy: 0.9869 - val_loss: 1.5410 - val_accuracy: 0.7409
# Epoch 41/50
# 196/196 [==============================] - 23s 120ms/step - loss: 0.0355 - accuracy: 0.9878 - val_loss: 2.5656 - val_accuracy: 0.6476
# Epoch 42/50
# 196/196 [==============================] - 23s 120ms/step - loss: 0.0398 - accuracy: 0.9859 - val_loss: 1.6329 - val_accuracy: 0.7257
# Epoch 43/50
# 196/196 [==============================] - 24s 120ms/step - loss: 0.0377 - accuracy: 0.9872 - val_loss: 1.6945 - val_accuracy: 0.7213
# Epoch 44/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0271 - accuracy: 0.9907 - val_loss: 1.6756 - val_accuracy: 0.7232
# Epoch 45/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 1.8970 - val_accuracy: 0.6936
# Epoch 46/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 1.7248 - val_accuracy: 0.7213
# Epoch 47/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0324 - accuracy: 0.9892 - val_loss: 1.9007 - val_accuracy: 0.6963
# Epoch 48/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 1.6837 - val_accuracy: 0.7271
# Epoch 49/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0328 - accuracy: 0.9889 - val_loss: 1.9868 - val_accuracy: 0.6871
# Epoch 50/50
# 196/196 [==============================] - 23s 119ms/step - loss: 0.0338 - accuracy: 0.9887 - val_loss: 2.0037 - val_accuracy: 0.7014
