# %% [markdown]
# ##Problem 4: generate and visualize the edges on the CIFAR-10, CIFAR-100, SVHN, and Tiny ImageNet datasets using DFF.

# %% [markdown]
# ###Installing required libraries

# %%
# !pip install torch==1.0.1
# Out:
# ...
#      |████████████████████████████████| 560.1 MB 26 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.0.1 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.0.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.0.1 which is incompatible.
# ...

# %%
# !pip install torchvision==0.2.2
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.7 MB/s
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Uninstalling tqdm-4.62.3:
#       Successfully uninstalled tqdm-4.62.3
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.0.1 which is incompatible.
# spacy 2.2.4 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.19.9 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.19.9 which is incompatible.
# ...

# %%
# !pip install ninja==1.8.2.post1
# Out:
# ...
#      |████████████████████████████████| 88 kB 4.2 MB/s
# ...

# %%
# !pip install portalocker

# %%
# !gdown https://drive.google.com/uc?id=1G34sH3JoSEcnpkqjClRdQqTwG4JKRi4-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1G34sH3JoSEcnpkqjClRdQqTwG4JKRi4-
# To: /content/DFF.zip
# 100% 673M/673M [00:03<00:00, 218MB/s]

# %%
# !unzip DFF.zip
# !rm DFF.zip
# Out:
# Archive:  DFF.zip
#    creating: DFF/
#   inflating: DFF/LICENSE
#    creating: DFF/exps/
#   inflating: DFF/exps/test.py
#    creating: DFF/exps/models/
#   inflating: DFF/exps/models/casenet.py
#    creating: DFF/exps/models/__pycache__/
#   inflating: DFF/exps/models/__pycache__/dff.cpython-37.pyc
#   inflating: DFF/exps/models/__pycache__/__init__.cpython-37.pyc
#   inflating: DFF/exps/models/__pycache__/base.cpython-37.pyc
#   inflating: DFF/exps/models/__pycache__/casenet.cpython-37.pyc
#   inflating: DFF/exps/models/base.py
#   inflating: DFF/exps/models/__init__.py
#   inflating: DFF/exps/models/dff.py
#    creating: DFF/exps/datasets/
#    creating: DFF/exps/datasets/__pycache__/
#   inflating: DFF/exps/datasets/__pycache__/cityscapes.cpython-37.pyc
#   inflating: DFF/exps/datasets/__pycache__/sbd.cpython-37.pyc
#   inflating: DFF/exps/datasets/__pycache__/base_sbd.cpython-37.pyc
#   inflating: DFF/exps/datasets/__pycache__/__init__.cpython-37.pyc
# ...

# %%
# !gdown https://drive.google.com/uc?id=1--P9shoJ5HUBBaIRS9EJDGsON2s6gfN5
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1--P9shoJ5HUBBaIRS9EJDGsON2s6gfN5
# To: /content/encoding.zip
# 100% 2.19M/2.19M [00:00<00:00, 69.1MB/s]

# %%
# !unzip encoding.zip
# !rm encoding.zip
# Out:
# Archive:  encoding.zip
#    creating: encoding/
#    creating: encoding/models/
#   inflating: encoding/models/psp.py
#   inflating: encoding/models/fcn.py
#   inflating: encoding/models/base.py
#   inflating: encoding/models/encnet.py
#   inflating: encoding/models/model_zoo.py
#   inflating: encoding/models/danet.py
#   inflating: encoding/models/plain.py
#   inflating: encoding/models/__init__.py
#   inflating: encoding/models/casenet.py
#   inflating: encoding/models/model_store.py
#   inflating: encoding/models/gcnet.py
#    creating: encoding/models/__pycache__/
#   inflating: encoding/models/__pycache__/psp.cpython-37.pyc
#   inflating: encoding/models/__pycache__/fcn.cpython-37.pyc
#   inflating: encoding/models/__pycache__/base.cpython-37.pyc
#   inflating: encoding/models/__pycache__/encnet.cpython-37.pyc
#   inflating: encoding/models/__pycache__/model_zoo.cpython-37.pyc
#   inflating: encoding/models/__pycache__/danet.cpython-37.pyc
# ...

# %%
# !mv ./encoding /usr/local/lib/python3.7/dist-packages

# %%
# !apt install octave
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn epstool fonts-droid-fallback fonts-noto-mono ghostscript gnuplot-data
#   gnuplot-qt gsfonts imagemagick-6-common info install-info libamd2
#   libauthen-sasl-perl libcamd2 libccolamd2 libcholmod3 libcolamd2
#   libcupsfilters1 libcupsimage2 libcxsparse3 libdata-dump-perl libemf1
#   libencode-locale-perl libfftw3-single3 libfile-listing-perl libfltk-gl1.3
#   libfltk1.3 libfont-afm-perl libgail-common libgail18 libglpk40
#   libgraphicsmagick++-q16-12 libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libijs-0.35 libio-html-perl
# ...

# %% [markdown]
# ###Necessary imports

# %%
import os
import cv2

# %% [markdown]
# ##Cifar-10

# %% [markdown]
# ###Downloading Data

# %%
# !gdown https://drive.google.com/uc?id=1-lqE73lkk0z9FQI6W_SieQkBwPgDrK0w
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-lqE73lkk0z9FQI6W_SieQkBwPgDrK0w
# To: /content/cifar10 original.zip
# 100% 24.0M/24.0M [00:00<00:00, 90.4MB/s]

# %%
# !rm -rf /content/DFF/data/cityscapes-preprocess/code/data_orig
# !rm -rf /content/DFF/data/cityscapes-preprocess/data_proc

# %%
cd /content
# Out:
# /content

# %%
# !unzip '/content/cifar10 original.zip'
# !rm '/content/cifar10 original.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: cifar10 original/data/0501 (10).png
#  extracting: cifar10 original/data/0501 (2).png
#  extracting: cifar10 original/data/0501 (3).png
#  extracting: cifar10 original/data/0501 (4).png
#  extracting: cifar10 original/data/0501 (5).png
#  extracting: cifar10 original/data/0501 (6).png
#  extracting: cifar10 original/data/0501 (7).png
#  extracting: cifar10 original/data/0501 (8).png
#  extracting: cifar10 original/data/0501 (9).png
#  extracting: cifar10 original/data/0501.png
#  extracting: cifar10 original/data/0502 (10).png
#  extracting: cifar10 original/data/0502 (2).png
#  extracting: cifar10 original/data/0502 (3).png
#  extracting: cifar10 original/data/0502 (4).png
#  extracting: cifar10 original/data/0502 (5).png
#  extracting: cifar10 original/data/0502 (6).png
#  extracting: cifar10 original/data/0502 (7).png
#  extracting: cifar10 original/data/0502 (8).png
# ...

# %%
# !mv '/content/cifar10 original' '/content/DFF/data/cityscapes-preprocess/code/data_orig'
# !mv '/content/DFF/data/cityscapes-preprocess/code/data_orig/data' '/content/DFF/data/cityscapes-preprocess/code/data_orig/test'

# %% [markdown]
# ###Data Preprocessing

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  r = f.replace(" ","")
  if( r != f):
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+r)

# %%
cd /content/DFF/data/cityscapes-preprocess/code
# Out:
# /content/DFF/data/cityscapes-preprocess/code

# %%
# !octave -W demoPreproc_gen_png_label.m
# Out:
# D
# E
# ans = 1
# Set: test
#   0%[                                                   ]
#
# 100%[...................................................]

# %%
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.mat' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.mat'
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.txt' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.txt'

# %% [markdown]
# ###Generating edges

# %%
cd /content/DFF/exps
# Out:
# /content/DFF/exps

# %%
# !rm -rf '/content/DFF/exps/cityscapes/dff/dff_vis'

# %%
# !python test.py --dataset cityscapes --model dff --checkname dff --workers 8 --backbone resnet101
# Out:
# ...
# 100% 174540/174540 [00:10<00:00, 16331.26KB/s]
# 100% 10000/10000 [09:43<00:00, 17.15it/s]

# %% [markdown]
# Generated edges are present at '/content/DFF/exps/cityscapes/dff/dff_vis

# %% [markdown]
# Generated edges are saved in a zip : [Cifar-10](https://drive.google.com/file/d/1-SfK9Tyu3WHZ6cP0Uij7ynHHaSBFI9nr/view?usp=sharing)

# %% [markdown]
# Sample of edges generated for Cifar-10 dataset using the model pretrained on cityscapes dataset.
#
# 0013(5)_fuse.png
# ![0013 (5).png](data:image/png;base64,...)
#
# 0011(9)_side5.png
# ![0011 (9).png](data:image/png;base64,...)
#
#
# 0006(2)_side5.png![0006 (2).png](data:image/png;base64,...)
#
#
# 0001(3)_side5.png![0001 (3).png](data:image/png;base64,...)
#
# 0007(3)_side5.png
# ![0007 (3).png](data:image/png;base64,...)
#
# 0010(7)_side5.png
# ![0010 (7).png](data:image/png;base64,...)

# %% [markdown]
# ##Cifar-100

# %% [markdown]
# ###Downloading Data

# %%
cd /content
# Out:
# /content

# %%
# !gdown https://drive.google.com/uc?id=1aQ3gVJ20viL4lO78_BysZR4uoFqhAUEG
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aQ3gVJ20viL4lO78_BysZR4uoFqhAUEG
# To: /content/cifar100 original.zip
# 100% 22.8M/22.8M [00:00<00:00, 139MB/s]

# %%
# !rm -rf /content/DFF/data/cityscapes-preprocess/code/data_orig
# !rm -rf /content/DFF/data/cityscapes-preprocess/data_proc

# %%
# !unzip '/content/cifar100 original.zip'
# !rm '/content/cifar100 original.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: cifar100 original/0048 (90).png
#  extracting: cifar100 original/0048 (91).png
#  extracting: cifar100 original/0048 (92).png
#  extracting: cifar100 original/0048 (93).png
#  extracting: cifar100 original/0048 (94).png
#  extracting: cifar100 original/0048 (95).png
#  extracting: cifar100 original/0048 (96).png
#  extracting: cifar100 original/0048.png
#  extracting: cifar100 original/0049 (10).png
#  extracting: cifar100 original/0049 (11).png
#  extracting: cifar100 original/0049 (12).png
#  extracting: cifar100 original/0049 (13).png
#  extracting: cifar100 original/0049 (14).png
#  extracting: cifar100 original/0049 (15).png
#  extracting: cifar100 original/0049 (16).png
#  extracting: cifar100 original/0049 (17).png
#  extracting: cifar100 original/0049 (18).png
#  extracting: cifar100 original/0049 (19).png
#  extracting: cifar100 original/0049 (2).png
#  extracting: cifar100 original/0049 (20).png
# ...

# %%
# !mv '/content/cifar100 original' '/content/DFF/data/cityscapes-preprocess/code/data_orig'

# %%
# !mkdir '/content/DFF/data/cityscapes-preprocess/code/data_orig/test'

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/"):
  if 'png' in f:
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f)

# %% [markdown]
# ###Data Preprocessing

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  r = f.replace(" ","")
  if( r != f):
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+r)

# %%
cd /content/DFF/data/cityscapes-preprocess/code
# Out:
# /content/DFF/data/cityscapes-preprocess/code

# %%
# !octave -W demoPreproc_gen_png_label.m
# Out:
# D
# E
# ans = 1
# Set: test
#   0%[                                                   ]
#
# 100%[...................................................]

# %%
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.mat' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.mat'
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.txt' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.txt'

# %% [markdown]
# ###Generating edges

# %%
cd /content/DFF/exps
# Out:
# /content/DFF/exps

# %%
# !rm -rf '/content/DFF/exps/cityscapes/dff/dff_vis'

# %%
# !python test.py --dataset cityscapes --model dff --checkname dff --workers 8 --backbone resnet101
# Out:
# ...
# 100% 174540/174540 [00:12<00:00, 14174.21KB/s]
# 100% 9600/9600 [09:22<00:00, 17.08it/s]

# %% [markdown]
# Generated edges are present at '/content/DFF/exps/cityscapes/dff/dff_vis'

# %% [markdown]
# Generated edges are saved in a zip : [Cifar-100](https://drive.google.com/file/d/1h58rExHOPwlDoEeYgynMsx7wkFZdoAYP/view?usp=sharing)

# %% [markdown]
# Sample of edges generated for Cifar-100 dataset using the model pretrained on cityscapes dataset.
#
# ![0002 (29).png](data:image/png;base64,...)
# 0002(29)_side5.png
#
# ![0001 (88).png](data:image/png;base64,...)
# 0001(88)_side5.png
#
#
# ![0001 (74).png](data:image/png;base64,...)
# 0001(74)_side5.png
#
# ![0001 (48).png](data:image/png;base64,...)
# 0001(48)_side5.png
#
# ![0001 (36).png](data:image/png;base64,...)
# 0001(36)_side5.png

# %% [markdown]
# ##SVHN

# %% [markdown]
# ###Downloading Data

# %%
cd /content
# Out:
# /content

# %%
# !gdown https://drive.google.com/uc?id=1HteD2X_jMLJXAycRsnwy1TJiiYe01KK-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1HteD2X_jMLJXAycRsnwy1TJiiYe01KK-
# To: /content/svhnog.zip
# 100% 272M/272M [00:01<00:00, 205MB/s]

# %%
# !rm -rf /content/DFF/data/cityscapes-preprocess/code/data_orig
# !rm -rf /content/DFF/data/cityscapes-preprocess/data_proc

# %%
# !unzip '/content/svhnog.zip'
# !rm '/content/svhnog.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: svhn/5499.png
#  extracting: svhn/55.png
#  extracting: svhn/550.png
#   inflating: svhn/5500.png
#  extracting: svhn/5501.png
#  extracting: svhn/5502.png
#  extracting: svhn/5503.png
#  extracting: svhn/5504.png
#   inflating: svhn/5505.png
#  extracting: svhn/5506.png
#  extracting: svhn/5507.png
#   inflating: svhn/5508.png
#  extracting: svhn/5509.png
#  extracting: svhn/551.png
#  extracting: svhn/5510.png
#  extracting: svhn/5511.png
#  extracting: svhn/5512.png
#   inflating: svhn/5513.png
#  extracting: svhn/5514.png
#  extracting: svhn/5515.png
#  extracting: svhn/5516.png
#  extracting: svhn/5517.png
#   inflating: svhn/5518.png
#  extracting: svhn/5519.png
#   inflating: svhn/552.png
#  extracting: svhn/5520.png
#  extracting: svhn/5521.png
#   inflating: svhn/5522.png
#  extracting: svhn/5523.png
#   inflating: svhn/5524.png
#  extracting: svhn/5525.png
#  extracting: svhn/5526.png
# ...

# %%
# !mv '/content/svhn' '/content/DFF/data/cityscapes-preprocess/code/data_orig'

# %%
# !mkdir '/content/DFF/data/cityscapes-preprocess/code/data_orig/test'

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/"):
  if 'png' in f:
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f)

# %% [markdown]
# ###Data Preprocessing

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  r = f.replace(" ","")
  if( r != f):
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+r)

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  img = cv2.imread('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f, cv2.IMREAD_UNCHANGED)
  dim = (224, 224)
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
  cv2.imwrite('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f, resized)

# %%
cd /content/DFF/data/cityscapes-preprocess/code
# Out:
# /content/DFF/data/cityscapes-preprocess/code

# %%
# !octave -W demoPreproc_gen_png_label.m
# Out:
# D
# E
# ans = 1
# Set: test
#   0%[                                                   ]
#
# 100%[...................................................]

# %%
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.mat' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.mat'
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.txt' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.txt'

# %% [markdown]
# ###Generating edges

# %%
cd /content/DFF/exps
# Out:
# /content/DFF/exps

# %%
# !rm -rf '/content/DFF/exps/cityscapes/dff/dff_vis'

# %%
# !python test.py --dataset cityscapes --model dff --checkname dff --workers 8 --backbone resnet101
# Out:
# ...
# 100% 174540/174540 [00:13<00:00, 13022.56KB/s]
# 100% 13068/13068 [1:12:33<00:00,  3.00it/s]

# %% [markdown]
# Generated edges are present at '/content/DFF/exps/cityscapes/dff/dff_vis'

# %% [markdown]
# Generated edges are saved in a zip : [SVHN](https://drive.google.com/file/d/1-28LX-RbEjNsdzmRfxnNsRRYyy7hhUAh/view?usp=sharing)

# %% [markdown]
# Sample of edges generated for SVHN dataset using the model pretrained on cityscapes dataset.
#
# ![168_side5.png](data:image/png;base64,...)
# ![168.png](data:image/png;base64,...)
#
# ![76.png](data:image/png;base64,...)![76_side5.png](data:image/png;base64,...)

# %% [markdown]
# ##Tiny ImageNet

# %% [markdown]
# ###Downloading Data

# %%
cd /content
# Out:
# /content

# %%
# !gdown https://drive.google.com/uc?id=1qyZRi-2B4HBE45vJaAJoEagD_dgO0vPn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qyZRi-2B4HBE45vJaAJoEagD_dgO0vPn
# To: /content/tinyimagenetog.zip
# 100% 19.8M/19.8M [00:00<00:00, 121MB/s]

# %%
# !rm -rf /content/DFF/data/cityscapes-preprocess/code/data_orig
# !rm -rf /content/DFF/data/cityscapes-preprocess/data_proc

# %%
# !unzip '/content/tinyimagenetog.zip'
# !rm '/content/tinyimagenetog.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tinyimagenet/test_5499.JPEG
#   inflating: tinyimagenet/test_55.JPEG
#   inflating: tinyimagenet/test_550.JPEG
#   inflating: tinyimagenet/test_5500.JPEG
#   inflating: tinyimagenet/test_5501.JPEG
#   inflating: tinyimagenet/test_5502.JPEG
#   inflating: tinyimagenet/test_5503.JPEG
#   inflating: tinyimagenet/test_5504.JPEG
#   inflating: tinyimagenet/test_5505.JPEG
#   inflating: tinyimagenet/test_5506.JPEG
#   inflating: tinyimagenet/test_5507.JPEG
#   inflating: tinyimagenet/test_5508.JPEG
#   inflating: tinyimagenet/test_5509.JPEG
#   inflating: tinyimagenet/test_551.JPEG
#   inflating: tinyimagenet/test_5510.JPEG
#   inflating: tinyimagenet/test_5511.JPEG
#   inflating: tinyimagenet/test_5512.JPEG
#   inflating: tinyimagenet/test_5513.JPEG
#   inflating: tinyimagenet/test_5514.JPEG
#   inflating: tinyimagenet/test_5515.JPEG
#   inflating: tinyimagenet/test_5516.JPEG
#   inflating: tinyimagenet/test_5517.JPEG
# ...

# %%
# !mv '/content/tinyimagenet' '/content/DFF/data/cityscapes-preprocess/code/data_orig'

# %%
# !mkdir '/content/DFF/data/cityscapes-preprocess/code/data_orig/test'

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/"):
  if 'JPEG' in f:
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f)

# %% [markdown]
# ###Data Preprocessing

# %%
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  r = f.replace(" ","")
  if( r != f):
    os.rename('/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+f,'/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+r)

# %%
import cv2
for f in os.listdir("/content/DFF/data/cityscapes-preprocess/code/data_orig/test/"):
  path1 = '/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+os.path.splitext(f)[0]+'.JPEG'
  path2 = '/content/DFF/data/cityscapes-preprocess/code/data_orig/test/'+os.path.splitext(f)[0]+'.png'
  img1 = cv2.imread(path1)
  cv2.imwrite(path2,img1)

# %%
cd /content/DFF/data/cityscapes-preprocess/code
# Out:
# /content/DFF/data/cityscapes-preprocess/code

# %%
# !octave -W demoPreproc_gen_png_label.m
# Out:
# D
# E
# ans = 1
# Set: test
#   0%[                                                   ]
#
# 100%[...................................................]

# %%
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.mat' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.mat'
# !mv '/content/DFF/data/cityscapes-preprocess/data_proc/test.txt' '/content/DFF/data/cityscapes-preprocess/data_proc/vis.txt'

# %% [markdown]
# ###Generating edges

# %%
cd /content/DFF/exps
# Out:
# /content/DFF/exps

# %%
# !rm -rf '/content/DFF/exps/cityscapes/dff/dff_vis'

# %%
# !python test.py --dataset cityscapes --model dff --checkname dff --workers 8 --backbone resnet101
# Out:
# ...
# 100% 174540/174540 [00:08<00:00, 21086.59KB/s]
# 100% 10000/10000 [07:21<00:00, 22.64it/s]

# %% [markdown]
# Generated edges are present at '/content/DFF/exps/cityscapes/dff/dff_vis'

# %% [markdown]
# Generated edges are saved in a zip : [Tiny ImageNet](https://drive.google.com/file/d/1OQ3Zwc51gC418hkvLRuSC_YHuX4UFAW4/view?usp=sharing)

# %% [markdown]
# Sample of edges generated for Tiny ImageNet dataset using the model pretrained on cityscapes dataset.
#
# ![test_63.JPEG](data:image/jpeg;base64,...)
# test_63_side5.png
#
# ![test_54.JPEG](data:image/jpeg;base64,...)
# ![test_54_side5.png](data:image/png;base64,...)
#
# ![test_30.JPEG](data:image/jpeg;base64,...)
# ![test_30_side5.png](data:image/png;base64,...)
#
# ![test_24.JPEG](data:image/jpeg;base64,...)
# ![test_24_side5.png](data:image/png;base64,...)
#
# ![test_17.JPEG](data:image/jpeg;base64,...)
# ![test_17_side5.png](data:image/png;base64,...)
